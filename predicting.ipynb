# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col = 0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk   pk pkatt  \
# 0  Crystal Palace  ...  Match Report    NaN  10.0  2.0  14.6  1.0  0.0   0.0
# 1  Leicester City  ...  Match Report    NaN  19.0  7.0  13.0  0.0  0.0   0.0
# 2     Bournemouth  ...  Match Report    NaN  14.0  6.0  14.8  0.0  0.0   0.0
# 3          Fulham  ...  Match Report    NaN  22.0  8.0  15.5  1.0  0.0   0.0
# 4     Aston Villa  ...  Match Report    NaN  22.0  8.0  16.3  1.0  0.0   0.0
#
#    season     team
# 0    2023  Arsenal
# 1    2023  Arsenal
# 2    2023  Arsenal
# 3    2023  Arsenal
# 4    2023  Arsenal
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1134, 27)

# %%
matches["team"].value_counts()
# Out:
# Leicester City              57
# Newcastle United            57
# Southampton                 57
# Tottenham Hotspur           57
# Everton                     57
# West Ham United             57
# Brentford                   57
# Wolverhampton Wanderers     57
# Chelsea                     57
# Aston Villa                 57
# Arsenal                     56
# Leeds United                56
# Crystal Palace              56
# Manchester City             56
# Liverpool                   56
# Brighton and Hove Albion    56
# Manchester United           56
# Burnley                     38
# Watford                     38
# Norwich City                38
# Fulham                      20
# Nottingham Forest           19
# Bournemouth                 19
# Name: team, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
# machine learning system can only deal with numbers without object so we have to cast some of the columns

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex = True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches.loc[matches['result'] == 'W', 'target'] = 2
matches.loc[matches['result'] == 'D', 'target'] = 1
matches.loc[matches['result'] == 'L', 'target'] = 0

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L  0.0
# 39 2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L  0.0
# 40 2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L  0.0
# 41 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  1.0
# 42 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L  0.0
#
#      ga        opponent  ...   fk   pk  pkatt  season          team  \
# 0   0.0  Crystal Palace  ...  1.0  0.0    0.0    2023       Arsenal
# 1   2.0  Leicester City  ...  0.0  0.0    0.0    2023       Arsenal
# 2   0.0     Bournemouth  ...  0.0  0.0    0.0    2023       Arsenal
# 3   1.0          Fulham  ...  1.0  0.0    0.0    2023       Arsenal
# 4   1.0     Aston Villa  ...  1.0  0.0    0.0    2023       Arsenal
# ..  ...             ...  ...  ...  ...    ...     ...           ...
# 38  2.0     Aston Villa  ...  0.0  0.0    0.0    2022  Norwich City
# 39  4.0        West Ham  ...  1.0  0.0    0.0    2022  Norwich City
# 40  3.0  Leicester City  ...  0.0  0.0    0.0    2022  Norwich City
# 41  1.0          Wolves  ...  0.0  0.0    0.0    2022  Norwich City
# 42  5.0       Tottenham  ...  0.0  0.0    0.0    2022  Norwich City
#
#    venue_code opp_code hour  day_code  target
# 0           0        7   20         4     2.0
# 1           1       11   15         5     2.0
# 2           0        2   17         5     2.0
# 3           1        9   17         5     2.0
# 4           1        1   19         2     2.0
# ..        ...      ...  ...       ...     ...
# 38          0        1   15         5     0.0
# 39          1       21   14         6     0.0
# 40          0       11   19         2     0.0
# 41          0       22   14         6     1.0
# 42          1       19   16         6     0.0
#
# [1134 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 50, min_samples_split = 10, random_state = 1)

# %%
train = matches[matches["date"] < '2022-07-01']

# %%
test = matches[matches["date"] > '2022-07-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
print(f'accuracy:', acc)
# Out:
# accuracy: 0.4037433155080214

# %%
# The results of the tests:

# %%
combined = pd.DataFrame(dict(actual = test["target"], prediction = preds))

# %%
pd.crosstab(index = combined["actual"], columns = combined["prediction"])
# Out:
# prediction  0.0  1.0  2.0
# actual
# 0.0          83   21   42
# 1.0          34    6   42
# 2.0          60   24   62

# %%
# checking the accuracy rate:

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds, average ='micro')
# Out:
# 0.4037433155080214

# %%
# in order to increase it we'll add more data like follows:

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D  3.0
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# 6  2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away      W  3.0
# 10 2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home      
2022-05-11  20:15  Premier League  Matchweek 33  Wed  Away      W  5.0
# 56 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  2.0
# 57 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W  3.0
#
#      ga         opponent  ...   fk   pk  pkatt  season             team  \
# 1   0.0         West Ham  ...  1.0  1.0    1.0    2023  Manchester City
# 2   0.0      Bournemouth  ...  0.0  0.0    0.0    2023  Manchester City
# 3   3.0    Newcastle Utd  ...  1.0  0.0    0.0    2023  Manchester City
# 4   2.0   Crystal Palace  ...  0.0  0.0    0.0    2023  Manchester City
# 5   0.0  Nott'ham Forest  ...  0.0  0.0    0.0    2023  Manchester City
# 6   1.0      Aston Villa  ...  1.0  0.0    0.0    2023  Manchester City
# 9   0.0           Wolves  ...  0.0  0.0    0.0    2023  Manchester City
# 10  3.0   Manchester Utd  ...  1.0  0.0    0.0    2023  Manchester City
# 12  0.0      Southampton  ...  0.0  0.0    0.0    2023  Manchester City
# 14  1.0        Liverpool  ...  0.0  0.0    0.0    2023  Manchester City
# 15  1.0         Brighton  ...  0.0  1.0    1.0    2023  Manchester City
# 17  0.0   Leicester City  ...  1.0  0.0    0.0    2023  Manchester City
# 19  1.0           Fulham  ...  1.0  1.0    1.0    2023  Manchester City
# 21  2.0        Brentford  ...  0.0  0.0    0.0    2023  Manchester City
# 23  1.0     Leeds United  ...  0.0  0.0    0.0    2023  Manchester City
# 24  1.0          Everton  ...  0.0  0.0    0.0    2023  Manchester City
# 25  0.0          Chelsea  ...  0.0  0.0    0.0    2023  Manchester City
# 28  2.0   Manchester Utd  ...  0.0  0.0    0.0    2023  Manchester City
# 1   1.0        Tottenham  ...  1.0  0.0    0.0    2022  Manchester City
# 2   0.0     Norwich City  ...  1.0  0.0    0.0    2022  Manchester City
# 3   0.0          Arsenal  ...  0.0  0.0    0.0    2022  Manchester City
# 4   0.0   Leicester City  ...  0.0  0.0    0.0    2022  Manchester City
# 6   0.0      Southampton  ...  1.0  0.0    0.0    2022  Manchester City
# 8   0.0          Chelsea  ...  0.0  0.0    0.0    2022  Manchester City
# 10  2.0        Liverpool  ...  1.0  0.0    0.0    2022  Manchester City
# 11  0.0          Burnley  ...  0.0  0.0    0.0    2022  Manchester City
# 13  1.0         Brighton  ...  1.0  0.0    0.0    2022  Manchester City
# 15  2.0   Crystal Palace  ...  0.0  0.0    0.0    2022  Manchester City
# 17  0.0   Manchester Utd  ...  0.0  0.0    0.0    2022  Manchester City
# 18  0.0          Everton  ...  1.0  0.0    0.0    2022  Manchester City
# 20  1.0         West Ham  ...  0.0  0.0    0.0    2022  Manchester City
# 21  1.0      Aston Villa  ...  1.0  0.0    0.0    2022  Manchester City
# 22  1.0          Watford  ...  0.0  0.0    0.0    2022  Manchester City
# 24  0.0           Wolves  ...  0.0  1.0    1.0    2022  Manchester City
# 25  0.0     Leeds United  ...  2.0  0.0    0.0    2022  Manchester City
# 26  0.0    Newcastle Utd  ...  0.0  0.0    0.0    2022  Manchester City
# 27  3.0   Leicester City  ...  1.0  2.0    2.0    2022  Manchester City
# 28  0.0        Brentford  ...  0.0  0.0    0.0    2022  Manchester City
# 29  1.0          Arsenal  ...  0.0  1.0    1.0    2022  Manchester City
# 31  0.0          Chelsea  ...  1.0  0.0    0.0    2022  Manchester City
# 32  1.0      Southampton  ...  0.0  0.0    0.0    2022  Manchester City
# 34  0.0        Brentford  ...  0.0  1.0    1.0    2022  Manchester City
# 35  0.0     Norwich City  ...  0.0  0.0    1.0    2022  Manchester City
# 37  3.0        Tottenham  ...  0.0  1.0    1.0    2022  Manchester City
# 38  0.0          Everton  ...  0.0  0.0    0.0    2022  Manchester City
# 40  1.0   Manchester Utd  ...  1.0  0.0    0.0    2022  Manchester City
# 42  0.0   Crystal Palace  ...  0.0  0.0    0.0    2022  Manchester City
# 44  0.0          Burnley  ...  0.0  0.0    0.0    2022  Manchester City
# 46  2.0        Liverpool  ...  1.0  0.0    0.0    2022  Manchester City
# 49  0.0         Brighton  ...  0.0  0.0    0.0    2022  Manchester City
# 50  1.0          Watford  ...  0.0  1.0    1.0    2022  Manchester City
# 52  0.0     Leeds United  ...  0.0  0.0    0.0    2022  Manchester City
# 54  0.0    Newcastle Utd  ...  1.0  0.0    0.0    2022  Manchester City
# 55  1.0           Wolves  ...  0.0  0.0    0.0    2022  Manchester City
# 56  2.0         West Ham  ...  2.0  0.0    1.0    2022  Manchester City
# 57  2.0      Aston Villa  ...  1.0  0.0    0.0    2022  Manchester City
#
#    venue_code opp_code hour  day_code  target
# 1           0       21   16         6     2.0
# 2           1        2   15         5     2.0
# 3           0       15   16         6     1.0
# 4           1        7   15         5     2.0
# 5           1       17   19         2     2.0
# 6           0        1   17         5     1.0
# 9           0       22   12         5     2.0
# 10          1       14   14         6     2.0
# 12          1       18   15         5     2.0
# 14          0       12   16         6     0.0
# 15          1        4   15         5     2.0
# 17          0       11   12         5     2.0
# 19          1        9   15         5     2.0
# 21          1        3   12         5     0.0
# 23          0       10   20         2     2.0
# 24          1        8   15         5     1.0
# 25          0        6   20         3     2.0
# 28          0       14   12         5     0.0
# 1           0       19   16         6     0.0
# 2           1       16   15         5     2.0
# 3           1        0   12         5     2.0
# 4           0       11   15         5     2.0
# 6           1       18   15         5     1.0
# 8           0        6   12         5     2.0
# 10          0       12   16         6     1.0
# 11          1        5   15         5     2.0
# 13          0        4   17         5     2.0
# 15          1        7   15         5     0.0
# 17          0       14   12         5     2.0
# 18          1        8   14         6     2.0
# 20          1       21   14         6     2.0
# 21          0        1   20         2     2.0
# 22          0       20   17         5     2.0
# 24          1       22   12         5     2.0
# 25          1       10   20         1     2.0
# 26          0       15   14         6     2.0
# 27          1       11   15         6     2.0
# 28          0        3   20         2     2.0
# 29          0        0   12         5     2.0
# 31          1        6   12         5     2.0
# 32          0       18   17         5     1.0
# 34          1        3   19         2     2.0
# 35          0       16   17         5     2.0
# 37          1       19   17         5     0.0
# 38          0        8   17         5     2.0
# 40          1       14   16         6     2.0
# 42          0        7   20         0     1.0
# 44          0        5   15         5     2.0
# 46          1       12   16         6     1.0
# 49          1        4   20         2     2.0
# 50          1       20   15         5     2.0
# 52          0       10   17         5     2.0
# 54          1       15   16         6     2.0
# 55          0       22   20         2     2.0
# 56          0       21   14         6     1.0
# 57          1        1   16         6     2.0
#
# [56 rows x 32 columns]

# %%
# below method will take in count the stats of 3 games before in order to take in count the momentum effect

# %%
def rolling_averages(group,cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed = 'left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk","pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
# now we get the table with calculated rolling stats:

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 4  2021-09-11  15:00  Premier League   Matchweek 4
#                         5  2021-09-18  15:00  Premier League   Matchweek 5
#                         7  2021-09-26  16:30  Premier League   Matchweek 6
#                         8  2021-10-02  17:30  Premier League   Matchweek 7
#                         9  2021-10-18  20:00  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 16 2022-11-12  19:45  Premier League  Matchweek 16
#                         18 2022-12-26  15:00  Premier League  Matchweek 17
#                         19 2022-12-31  12:30  Premier League  Matchweek 18
#                         20 2023-01-04  20:00  Premier League  Matchweek 19
#                         23 2023-01-14  15:00  Premier League  Matchweek 20
#
#                             day venue result   gf   ga        opponent  ...  \
# team                                                                    ...
# Arsenal                 4   Sat  Home      W  1.0  0.0    Norwich City  ...
#                         5   Sat  Away      W  1.0  0.0         Burnley  ...
#                         7   Sun  Home      W  3.0  1.0       Tottenham  ...
#                         8   Sat  Away      D  0.0  0.0        Brighton  ...
#                         9   Mon  Home      D  2.0  2.0  Crystal Palace  ...
# ...                         ...   ...    ...  ...  ...             ...  ...
# Wolverhampton Wanderers 16  Sat  Home      L  0.0  2.0         Arsenal  ...
#                         18  Mon  Away      W  2.0  1.0         Everton  ...
#                         19  Sat  Home      L  0.0  1.0  Manchester Utd  ...
#                         20  Wed  Away      D  1.0  1.0     Aston Villa  ...
#                         23  Sat  Home      W  1.0  0.0        West Ham  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 4          5     2.0    0.000000    3.000000
#                         5          5     2.0    0.333333    2.333333
#                         7          6     2.0    0.666667    1.666667
#                         8          5     1.0    1.666667    0.333333
#                         9          0     1.0    1.333333    0.333333
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 16         5     0.0    1.000000    2.666667
#                         18         0     2.0    1.000000    2.000000
#                         19         5     0.0    1.333333    2.000000
#                         20         2     1.0    0.666667    1.333333
#                         23         5     2.0    1.000000    1.000000
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 4    9.666667    2.333333    14.833333   0.333333
#                         5   12.333333    3.000000    14.133333   0.333333
#                         7   14.666667    3.000000    14.800000   0.666667
#                         8   18.333333    5.333333    18.433333   0.666667
#                         9   11.000000    4.000000    19.833333   0.666667
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 16  13.666667    4.333333    18.133333   0.333333
#                         18  10.333333    3.333333    19.566667   0.333333
#                         19   8.333333    3.333333    18.966667   0.333333
#                         20   9.333333    3.000000    18.633333   1.000000
#                         23   9.000000    3.333333    16.700000   0.666667
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 4     0.000000       0.000000
#                         5     0.000000       0.000000
#                         7     0.000000       0.000000
#                         8     0.000000       0.000000
#                         9     0.000000       0.000000
# ...                                ...            ...
# Wolverhampton Wanderers 16    0.333333       0.333333
#                         18    0.333333       0.333333
#                         19    0.333333       0.333333
#                         20    0.000000       0.000000
#                         23    0.000000       0.000000
#
# [1065 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0
# 5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0
# 7  2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W  3.0
# 8  2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D  0.0
# 9  2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
#
000000
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0      9.666667    2.333333    14.833333   0.333333    0.000000       0.000000
# 1     12.333333    3.000000    14.133333   0.333333    0.000000       0.000000
# 2     14.666667    3.000000    14.800000   0.666667    0.000000       0.000000
# 3     18.333333    5.333333    18.433333   0.666667    0.000000       0.000000
# 4     11.000000    4.000000    19.833333   0.666667    0.000000       0.000000
# ...         ...         ...          ...        ...         ...            ...
# 1060  13.666667    4.333333    18.133333   0.333333    0.333333       0.333333
# 1061  10.333333    3.333333    19.566667   0.333333    0.333333       0.333333
# 1062   8.333333    3.333333    18.966667   0.333333    0.333333       0.333333
# 1063   9.333333    3.000000    18.633333   1.000000    0.000000       0.000000
# 1064   9.000000    3.333333    16.700000   0.666667    0.000000       0.000000
#
# [1065 rows x 40 columns]

# %%
# below method will create predictions for the model with new tables for future improvments

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-07-01']
    test = data[data["date"] > '2022-07-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual = test["target"], predicted = preds), index = test.index)
    precision = precision_score(test["target"], preds, average ='micro')
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
print(f'precision:', precision)
# Out:
# precision: 0.4958904109589041

# %%
# we got improvment of 0.09% and almost total of 50% which is way better than random gambling which has 33.333% wining-rate

# %%
combined
# Out:
#       actual  predicted
# 35       2.0        0.0
# 36       2.0        2.0
# 37       2.0        2.0
# 38       2.0        2.0
# 39       2.0        2.0
# ...      ...        ...
# 1060     0.0        0.0
# 1061     2.0        1.0
# 1062     0.0        0.0
# 1063     1.0        2.0
# 1064     2.0        2.0
#
# [365 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index = True, right_index = True)

# %%
combined
# Out:
#       actual  predicted       date                     team        opponent  \
# 35       2.0        0.0 2022-08-05                  Arsenal  Crystal Palace
# 36       2.0        2.0 2022-08-13                  Arsenal  Leicester City
# 37       2.0        2.0 2022-08-20                  Arsenal     Bournemouth
# 38       2.0        2.0 2022-08-27                  Arsenal          Fulham
# 39       2.0        2.0 2022-08-31                  Arsenal     Aston Villa
# ...      ...        ...        ...                      ...             ...
# 1060     0.0        0.0 2022-11-12  Wolverhampton Wanderers         Arsenal
# 1061     2.0        1.0 2022-12-26  Wolverhampton Wanderers         Everton
# 1062     0.0        0.0 2022-12-31  Wolverhampton Wanderers  Manchester Utd
# 1063     1.0        2.0 2023-01-04  Wolverhampton Wanderers     Aston Villa
# 1064     2.0        2.0 2023-01-14  Wolverhampton Wanderers        West Ham
#
#      result
# 35        W
# 36        W
# 37        W
# 38        W
# 39        W
# ...     ...
# 1060      L
# 1061      W
# 1062      L
# 1063      D
# 1064      W
#
# [365 rows x 6 columns]

# %%
class MissingDic(dict):
    __missing__ = lambda self, key: key
    
map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
}    

mapping = MissingDic(**map_values)

# %%
mapping["Wolverhampton Wanderers"]
# Out:
# 'Wolves'

# %%
combined["team"] = combined["team"].map(mapping)

# %%
combined.to_csv("predictions.csv")

# %%
combined["isRight"] = combined["predicted"] == combined["actual"]

# %%
combined
# Out:
#       actual  predicted       date     team        opponent result new_team  \
# 35       2.0        0.0 2022-08-05  Arsenal  Crystal Palace      W  Arsenal
# 36       2.0        2.0 2022-08-13  Arsenal  Leicester City      W  Arsenal
# 37       2.0        2.0 2022-08-20  Arsenal     Bournemouth      W  Arsenal
# 38       2.0        2.0 2022-08-27  Arsenal          Fulham      W  Arsenal
# 39       2.0        2.0 2022-08-31  Arsenal     Aston Villa      W  Arsenal
# ...      ...        ...        ...      ...             ...    ...      ...
# 1060     0.0        0.0 2022-11-12   Wolves         Arsenal      L   Wolves
# 1061     2.0        1.0 2022-12-26   Wolves         Everton      W   Wolves
# 1062     0.0        0.0 2022-12-31   Wolves  Manchester Utd      L   Wolves
# 1063     1.0        2.0 2023-01-04   Wolves     Aston Villa      D   Wolves
# 1064     2.0        2.0 2023-01-14   Wolves        West Ham      W   Wolves
#
#       isRight
# 35      False
# 36       True
# 37       True
# 38       True
# 39       True
# ...       ...
# 1060     True
# 1061    False
# 1062     True
# 1063    False
# 1064     True
#
# [365 rows x 8 columns]

# %%
merged = combined.merge(combined, left_on =["date", "new_team"], right_on =["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0         2.0          0.0 2022-08-05                  Arsenal
# 1         2.0          2.0 2022-08-13                  Arsenal
# 2         2.0          2.0 2022-08-27                  Arsenal
# 3         2.0          2.0 2022-08-31                  Arsenal
# 4         0.0          2.0 2022-09-04                  Arsenal
# ..        ...          ...        ...                      ...
# 335       0.0          0.0 2022-11-12  Wolverhampton Wanderers
# 336       2.0          1.0 2022-12-26  Wolverhampton Wanderers
# 337       0.0          0.0 2022-12-31  Wolverhampton Wanderers
# 338       1.0          2.0 2023-01-04  Wolverhampton Wanderers
# 339       2.0          2.0 2023-01-14  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0    Crystal Palace        W    Arsenal       0.0          0.0
# 1    Leicester City        W    Arsenal       0.0          0.0
# 2            Fulham        W    Arsenal       0.0          0.0
# 3       Aston Villa        W    Arsenal       0.0          0.0
# 4    Manchester Utd        L    Arsenal       2.0          0.0
# ..              ...      ...        ...       ...          ...
# 335         Arsenal        L     Wolves       2.0          2.0
# 336         Everton        W     Wolves       0.0          2.0
# 337  Manchester Utd        L     Wolves       2.0          2.0
# 338     Aston Villa        D     Wolves       1.0          0.0
# 339        West Ham        W     Wolves       0.0          2.0
#
#                 team_y opponent_y result_y      new_team_y
# 0       Crystal Palace    Arsenal        L  Crystal Palace
# 1       Leicester City    Arsenal        L  Leicester City
# 2               Fulham    Arsenal        L          Fulham
# 3          Aston Villa    Arsenal        L     Aston Villa
# 4    Manchester United    Arsenal        W  Manchester Utd
# ..                 ...        ...      ...             ...
# 335            Arsenal     Wolves        W         Arsenal
# 336            Everton     Wolves        L         Everton
# 337  Manchester United     Wolves        W  Manchester Utd
# 338        Aston Villa     Wolves        D     Aston Villa
# 339    West Ham United     Wolves        L        West Ham
#
# [340 rows x 13 columns]
